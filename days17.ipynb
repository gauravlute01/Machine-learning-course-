# %% [markdown]
# # days17

# %%
import pandas as pd 
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 133.983,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.704,
#    'vote_count': 25650},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 124.166,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.696,
#    'vote_count': 19502},
#   {'adult': False,
#    'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg',
#    'genre_ids': [18, 80],
#    'id': 240,
#    'original_language': 'en',
#    'original_title': 'The Godfather Part II',
#    'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.',
#    'popularity': 74.94,
#    'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg',
#    'release_date': '1974-12-20',
#    'title': 'The Godfather Part II',
#    'video': False,
#    'vote_average': 8.577,
#    'vote_count': 11783},
#   {'adult': False,
#    'backdrop_path': '/3f92DMBTFqr3wgXpfxzrb0qv8nG.jpg',
#    'genre_ids': [18, 36, 10752],
#    'id': 424,
#    'original_language': 'en',
#    'original_title': "Schindler's List",
#    'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.',
#    'popularity': 95.181,
#    'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg',
#    'release_date': '1993-12-15',
#    'title': "Schindler's List",
#    'video': False,
#    'vote_average': 8.566,
#    'vote_count': 15157},
#   {'adult': False,
#    'backdrop_path': '/mSDsSDwaP3E7dEfUPWy4J0djt4O.jpg',
#    'genre_ids': [16, 10751, 14],
#    'id': 129,
#    'original_language': 'ja',
#    'original_title': '千と千尋の神隠し',
#    'overview': 'A young girl, Chihiro, becomes trapped in a strange new world of spirits. When her parents undergo a mysterious transformation, she must call upon the courage she never knew she had to free her family.',
#    'popularity': 93.91,
#    'poster_path': '/39wmItIWsg5sZMyRUHLkWBcuVCM.jpg',
#    'release_date': '2001-07-20',
#    'title': 'Spirited Away',
#    'video': False,
#    'vote_average': 8.539,
#    'vote_count': 15558},
#   {'adult': False,
#    'backdrop_path': '/qqHQsStV6exghCM7zbObuYBiYxw.jpg',
#    'genre_ids': [18],
#    'id': 389,
#    'original_language': 'en',
#    'original_title': '12 Angry Men',
#    'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.",
#    'popularity': 69.802,
#    'poster_path': '/ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg',
#    'release_date': '1957-04-10',
#    'title': '12 Angry Men',
#    'video': False,
#    'vote_average': 8.537,
#    'vote_count': 8067},
#   {'adult': False,
#    'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 19404,
#    'original_language': 'hi',
#    'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#    'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#    'popularity': 41.212,
#    'poster_path': '/lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg',
#    'release_date': '1995-10-20',
#    'title': 'Dilwale Dulhania Le Jayenge',
#    'video': False,
#    'vote_average': 8.535,
#    'vote_count': 4345},
#   {'adult': False,
#    'backdrop_path': '/nMKdUUepR0i5zn0y1T4CsSB5chy.jpg',
#    'genre_ids': [18, 28, 80, 53],
#    'id': 155,
#    'original_language': 'en',
#    'original_title': 'The Dark Knight',
#    'overview': 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.',
#    'popularity': 109.044,
#    'poster_path': '/qJ2tW6WMUDux911r6m7haRef0WH.jpg',
#    'release_date': '2008-07-16',
#    'title': 'The Dark Knight',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 31504},
#   {'adult': False,
#    'backdrop_path': '/hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg',
#    'genre_ids': [35, 53, 18],
#    'id': 496243,
#    'original_language': 'ko',
#    'original_title': '기생충',
#    'overview': "All unemployed, Ki-taek's family takes peculiar interest in the wealthy and glamorous Parks for their livelihood until they get entangled in an unexpected incident.",
#    'popularity': 122.501,
#    'poster_path': '/7IiTTgloJzvGI1TAYymCfbfl3vT.jpg',
#    'release_date': '2019-05-30',
#    'title': 'Parasite',
#    'video': False,
#    'vote_average': 8.509,
#    'vote_count': 17148},
#   {'adult': False,
#    'backdrop_path': '/l6hQWH9eDksNJNiXWYRkWqikOdu.jpg',
#    'genre_ids': [14, 18, 80],
#    'id': 497,
#    'original_language': 'en',
#    'original_title': 'The Green Mile',
#    'overview': "A supernatural tale set on death row in a Southern prison, where gentle giant John Coffey possesses the mysterious power to heal people's ailments. When the cell block's head guard, Paul Edgecomb, recognizes Coffey's miraculous gift, he tries desperately to help stave off the condemned man's execution.",
#    'popularity': 70.369,
#    'poster_path': '/8VG8fDNiy50H4FedGwdSVUPoaJe.jpg',
#    'release_date': '1999-12-10',
#    'title': 'The Green Mile',
#    'video': False,
#    'vote_average': 8.508,
#    'vote_count': 16520},
#   {'adult': False,
#    'backdrop_path': '/dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg',
#    'genre_ids': [16, 10749, 18],
#    'id': 372058,
#    'original_language': 'ja',
#    'original_title': '君の名は。',
#    'overview': 'High schoolers Mitsuha and Taki are complete strangers living separate lives. But one night, they suddenly switch places. Mitsuha wakes up in Taki’s body, and he in hers. This bizarre occurrence continues to happen randomly, and the two must adjust their lives around each other.',
#    'popularity': 71.225,
#    'poster_path': '/q719jXXEzOoYaps6babgKnONONX.jpg',
#    'release_date': '2016-08-26',
#    'title': 'Your Name.',
#    'video': False,
#    'vote_average': 8.497,
#    'vote_count': 10772},
#   {'adult': False,
#    'backdrop_path': '/suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg',
#    'genre_ids': [53, 80],
#    'id': 680,
#    'original_language': 'en',
#    'original_title': 'Pulp Fiction',
#    'overview': "A burger-loving hit man, his philosophical partner, a drug-addled gangster's moll and a washed-up boxer converge in this sprawling, comedic crime caper. Their adventures unfurl in three stories that ingeniously trip back and forth in time.",
#    'popularity': 129.35,
#    'poster_path': '/d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg',
#    'release_date': '1994-09-10',
#    'title': 'Pulp Fiction',
#    'video': False,
#    'vote_average': 8.49,
#    'vote_count': 26686},
#   {'adult': False,
#    'backdrop_path': '/qdIMHd4sEfJSckfVJfKQvisL02a.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 13,
#    'original_language': 'en',
#    'original_title': 'Forrest Gump',
#    'overview': 'A man with a low IQ has accomplished great things in his life and been present during significant historic events—in each case, far exceeding what anyone imagined he could do. But despite all he has achieved, his one true love eludes him.',
#    'popularity': 143.242,
#    'poster_path': '/arw2vcBveWOVZr6pxd9XTd1TdQa.jpg',
#    'release_date': '1994-06-23',
#    'title': 'Forrest Gump',
#    'video': False,
#    'vote_average': 8.477,
#    'vote_count': 26210},
#   {'adult': False,
#    'backdrop_path': '/2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg',
#    'genre_ids': [12, 14, 28],
#    'id': 122,
#    'original_language': 'en',
#    'original_title': 'The Lord of the Rings: The Return of the King',
#    'overview': "Aragorn is revealed as the heir to the ancient kings as he, Gandalf and the other members of the broken fellowship struggle to save Gondor from Sauron's forces. Meanwhile, Frodo and Sam take the ring closer to the heart of Mordor, the dark lord's realm.",
#    'popularity': 116.166,
#    'poster_path': '/rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg',
#    'release_date': '2003-12-01',
#    'title': 'The Lord of the Rings: The Return of the King',
#    'video': False,
#    'vote_average': 8.476,
#    'vote_count': 23067},
#   {'adult': False,
#    'backdrop_path': '/sw7mordbZxgITU877yTpZCud90M.jpg',
#    'genre_ids': [18, 80],
#    'id': 769,
#    'original_language': 'en',
#    'original_title': 'GoodFellas',
#    'overview': 'The true story of Henry Hill, a half-Irish, half-Sicilian Brooklyn kid who is adopted by neighbourhood gangsters at an early age and climbs the ranks of a Mafia family under the guidance of Jimmy Conway.',
#    'popularity': 69.437,
#    'poster_path': '/aKuFiU82s5ISJpGZp7YkIr3kCUd.jpg',
#    'release_date': '1990-09-12',
#    'title': 'GoodFellas',
#    'video': False,
#    'vote_average': 8.467,
#    'vote_count': 12170},
#   {'adult': False,
#    'backdrop_path': '/x4biAVdPVCghBlsVIzB6NmbghIz.jpg',
#    'genre_ids': [37],
#    'id': 429,
#    'original_language': 'it',
#    'original_title': 'Il buono, il brutto, il cattivo',
#    'overview': 'While the Civil War rages on between the Union and the Confederacy, three men – a quiet loner, a ruthless hitman, and a Mexican bandit – comb the American Southwest in search of a strongbox containing $200,000 in stolen gold.',
#    'popularity': 56.871,
#    'poster_path': '/bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg',
#    'release_date': '1966-12-22',
#    'title': 'The Good, the Bad and the Ugly',
#    'video': False,
#    'vote_average': 8.466,
#    'vote_count': 8093},
#   {'adult': False,
#    'backdrop_path': '/dlC0ed9Ugh3FzydnkBtV5lRXUu4.jpg',
#    'genre_ids': [16, 18, 10752],
#    'id': 12477,
#    'original_language': 'ja',
#    'original_title': '火垂るの墓',
#    'overview': 'In the final months of World War II, 14-year-old Seita and his sister Setsuko are orphaned when their mother is killed during an air raid in Kobe, Japan. After a falling out with their aunt, they move into an abandoned bomb shelter. With no surviving relatives and their emergency rations depleted, Seita and Setsuko struggle to survive.',
#    'popularity': 0.6,
#    'poster_path': '/k9tv1rXZbOhH7eiCk378x61kNQ1.jpg',
#    'release_date': '1988-04-16',
#    'title': 'Grave of the Fireflies',
#    'video': False,
#    'vote_average': 8.46,
#    'vote_count': 5118},
#   {'adult': False,
#    'backdrop_path': '/zoVeIgKzGJzpdG6Gwnr7iOYfIMU.jpg',
#    'genre_ids': [18, 10749],
#    'id': 11216,
#    'original_language': 'it',
#    'original_title': 'Nuovo Cinema Paradiso',
#    'overview': "A filmmaker recalls his childhood, when he fell in love with the movies at his village's theater and formed a deep friendship with the theater's projectionist.",
#    'popularity': 41.643,
#    'poster_path': '/8SRUfRUi6x4O68n0VCbDNRa6iGL.jpg',
#    'release_date': '1988-11-17',
#    'title': 'Cinema Paradiso',
#    'video': False,
#    'vote_average': 8.454,
#    'vote_count': 4124},
#   {'adult': False,
#    'backdrop_path': '/qvZ91FwMq6O47VViAr8vZNQz3WI.jpg',
#    'genre_ids': [28, 18],
#    'id': 346,
#    'original_language': 'ja',
#    'original_title': '七人の侍',
#    'overview': "A samurai answers a village's request for protection after he falls on hard times. The town needs protection from bandits, so the samurai gathers six others to help him teach the people how to defend themselves, and the villagers provide the soldiers with food.",
#    'popularity': 35.129,
#    'poster_path': '/8OKmBV5BUFzmozIC3pPWKHy17kx.jpg',
#    'release_date': '1954-04-26',
#    'title': 'Seven Samurai',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 3409},
#   {'adult': False,
#    'backdrop_path': '/gavyCu1UaTaTNPsVaGXT6pe5u24.jpg',
#    'genre_ids': [35, 18],
#    'id': 637,
#    'original_language': 'it',
#    'original_title': 'La vita è bella',
#    'overview': 'A touching story of an Italian book seller of Jewish ancestry who lives in his own little fairy tale. His creative and happy life would come to an abrupt halt when his entire family is deported to a concentration camp during World War II. While locked up he tries to convince his son that the whole thing is just a game.',
#    'popularity': 38.359,
#    'poster_path': '/6tEJnof1DKWPnl5lzkjf0FVv7oB.jpg',
#    'release_date': '1997-12-20',
#    'title': 'Life Is Beautiful',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 12578}],
#  'total_pages': 460,
#  'total_results': 9187}

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg          [18, 80]     278
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]     238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3   False  /3f92DMBTFqr3wgXpfxzrb0qv8nG.jpg   [18, 36, 10752]     424
# 4   False  /mSDsSDwaP3E7dEfUPWy4J0djt4O.jpg   [16, 10751, 14]     129
# 5   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]     389
# 6   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]   19404
# 7   False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  [18, 28, 80, 53]     155
# 8   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]  496243
# 9   False  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg      [14, 18, 80]     497
# 10  False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg   [16, 10749, 18]  372058
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]     680
# 12  False  /qdIMHd4sEfJSckfVJfKQvisL02a.jpg   [35, 18, 10749]      13
# 13  False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg      [12, 14, 28]     122
# 14  False  /sw7mordbZxgITU877yTpZCud90M.jpg          [18, 80]     769
# 15  False  /x4biAVdPVCghBlsVIzB6NmbghIz.jpg              [37]     429
# 16  False  /dlC0ed9Ugh3FzydnkBtV5lRXUu4.jpg   [16, 18, 10752]   12477
# 17  False  /zoVeIgKzGJzpdG6Gwnr7iOYfIMU.jpg       [18, 10749]   11216
# 18  False  /qvZ91FwMq6O47VViAr8vZNQz3WI.jpg          [28, 18]     346
# 19  False  /gavyCu1UaTaTNPsVaGXT6pe5u24.jpg          [35, 18]     637
#
#    original_language                                 original_title  \
# 0                 en                       The Shawshank Redemption
# 1                 en                                  The Godfather
# 2                 en                          The Godfather Part II
# 3                 en                               Schindler's List
# 4                 ja                                       千と千尋の神隠し
# 5                 en                                   12 Angry Men
# 6                 hi                   दिलवाले दुल्हनिया ले जायेंगे
# 7                 en                                The Dark Knight
# 8                 ko                                            기생충
# 9                 en                                 The Green Mile
# 10                ja                                          君の名は。
# 11                en                                   Pulp Fiction
# 12                en                                   Forrest Gump
# 13                en  The Lord of the Rings: The Return of the King
# 14                en                                     GoodFellas
# 15                it                Il buono, il brutto, il cattivo
# 16                ja                                          火垂るの墓
# 17                it                          Nuovo Cinema Paradiso
# 18                ja                                           七人の侍
# 19                it                                La vita è bella
#
#                                              overview  popularity  \
# 0   Framed in the 1940s for the double murder of h...     133.983
# 1   Spanning the years 1945 to 1955, a chronicle o...     124.166
# 2   In the continuing saga of the Corleone crime f...      74.940
# 3   The true story of how businessman Oskar Schind...      95.181
# 4   A young girl, Chihiro, becomes trapped in a st...      93.910
# 5   The defense and the prosecution have rested an...      69.802
# 6   Raj is a rich, carefree, happy-go-lucky second...      41.212
# 7   Batman raises the stakes in his war on crime. ...     109.044
# 8   All unemployed, Ki-taek's family takes peculia...     122.501
# 9   A supernatural tale set on death row in a Sout...      70.369
# 10  High schoolers Mitsuha and Taki are complete s...      71.225
# 11  A burger-loving hit man, his philosophical par...     129.350
# 12  A man with a low IQ has accomplished great thi...     143.242
# 13  Aragorn is revealed as the heir to the ancient...     116.166
# 14  The true story of Henry Hill, a half-Irish, ha...      69.437
# 15  While the Civil War rages on between the Union...      56.871
# 16  In the final months of World War II, 14-year-o...       0.600
# 17  A filmmaker recalls his childhood, when he fel...      41.643
# 18  A samurai answers a village's request for prot...      35.129
# 19  A touching story of an Italian book seller of ...      38.359
#
#                          poster_path release_date  \
# 0   /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23
# 1   /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14
# 2   /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20
# 3   /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15
# 4   /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg   2001-07-20
# 5   /ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg   1957-04-10
# 6   /lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg   1995-10-20
# 7   /qJ2tW6WMUDux911r6m7haRef0WH.jpg   2008-07-16
# 8   /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg   2019-05-30
# 9   /8VG8fDNiy50H4FedGwdSVUPoaJe.jpg   1999-12-10
# 10  /q719jXXEzOoYaps6babgKnONONX.jpg   2016-08-26
# 11  /d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg   1994-09-10
# 12  /arw2vcBveWOVZr6pxd9XTd1TdQa.jpg   1994-06-23
# 13  /rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg   2003-12-01
# 14  /aKuFiU82s5ISJpGZp7YkIr3kCUd.jpg   1990-09-12
# 15  /bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg   1966-12-22
# 16  /k9tv1rXZbOhH7eiCk378x61kNQ1.jpg   1988-04-16
# 17  /8SRUfRUi6x4O68n0VCbDNRa6iGL.jpg   1988-11-17
# 18  /8OKmBV5BUFzmozIC3pPWKHy17kx.jpg   1954-04-26
# 19  /6tEJnof1DKWPnl5lzkjf0FVv7oB.jpg   1997-12-20
#
#                                             title  video  vote_average  \
# 0                        The Shawshank Redemption  False         8.704
# 1                                   The Godfather  False         8.696
# 2                           The Godfather Part II  False         8.577
# 3                                Schindler's List  False         8.566
# 4                                   Spirited Away  False         8.539
# 5                                    12 Angry Men  False         8.537
# 6                     Dilwale Dulhania Le Jayenge  False         8.535
# 7                                 The Dark Knight  False         8.500
# 8                                        Parasite  False         8.509
# 9                                  The Green Mile  False         8.508
# 10                                     Your Name.  False         8.497
# 11                                   Pulp Fiction  False         8.490
# 12                                   Forrest Gump  False         8.477
# 13  The Lord of the Rings: The Return of the King  False         8.476
# 14                                     GoodFellas  False         8.467
# 15                 The Good, the Bad and the Ugly  False         8.466
# 16                         Grave of the Fireflies  False         8.460
# 17                                Cinema Paradiso  False         8.454
# 18                                  Seven Samurai  False         8.500
# 19                              Life Is Beautiful  False         8.500
#
#     vote_count
# 0        25650
# 1        19502
# 2        11783
# 3        15157
# 4        15558
# 5         8067
# 6         4345
# 7        31504
# 8        17148
# 9        16520
# 10       10772
# 11       26686
# 12       26210
# 13       23067
# 14       12170
# 15        8093
# 16        5118
# 17        4124
# 18        3409
# 19       12578

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      129                                  Spirited Away
# 5      389                                   12 Angry Men
# 6    19404                    Dilwale Dulhania Le Jayenge
# 7      155                                The Dark Knight
# 8   496243                                       Parasite
# 9      497                                 The Green Mile
# 10  372058                                     Your Name.
# 11     680                                   Pulp Fiction
# 12      13                                   Forrest Gump
# 13     122  The Lord of the Rings: The Return of the King
# 14     769                                     GoodFellas
# 15     429                 The Good, the Bad and the Ugly
# 16   12477                         Grave of the Fireflies
# 17   11216                                Cinema Paradiso
# 18     346                                  Seven Samurai
# 19     637                              Life Is Beautiful
#
#                                              overview release_date  \
# 0   Framed in the 1940s for the double murder of h...   1994-09-23
# 1   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2   In the continuing saga of the Corleone crime f...   1974-12-20
# 3   The true story of how businessman Oskar Schind...   1993-12-15
# 4   A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# 5   The defense and the prosecution have rested an...   1957-04-10
# 6   Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 7   Batman raises the stakes in his war on crime. ...   2008-07-16
# 8   All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 9   A supernatural tale set on death row in a Sout...   1999-12-10
# 10  High schoolers Mitsuha and Taki are complete s...   2016-08-26
# 11  A burger-loving hit man, his philosophical par...   1994-09-10
# 12  A man with a low IQ has accomplished great thi...   1994-06-23
# 13  Aragorn is revealed as the heir to the ancient...   2003-12-01
# 14  The true story of Henry Hill, a half-Irish, ha...   1990-09-12
# 15  While the Civil War rages on between the Union...   1966-12-22
# 16  In the final months of World War II, 14-year-o...   1988-04-16
# 17  A filmmaker recalls his childhood, when he fel...   1988-11-17
# 18  A samurai answers a village's request for prot...   1954-04-26
# 19  A touching story of an Italian book seller of ...   1997-12-20
#
#     popularity  vote_average  vote_count
# 0      133.983         8.704       25650
# 1      124.166         8.696       19502
# 2       74.940         8.577       11783
# 3       95.181         8.566       15157
# 4       93.910         8.539       15558
# 5       69.802         8.537        8067
# 6       41.212         8.535        4345
# 7      109.044         8.500       31504
# 8      122.501         8.509       17148
# 9       70.369         8.508       16520
# 10      71.225         8.497       10772
# 11     129.350         8.490       26686
# 12     143.242         8.477       26210
# 13     116.166         8.476       23067
# 14      69.437         8.467       12170
# 15      56.871         8.466        8093
# 16       0.600         8.460        5118
# 17      41.643         8.454        4124
# 18      35.129         8.500        3409
# 19      38.359         8.500       12578

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  129             Spirited Away
#
#                                             overview release_date  popularity  \
# 0  Framed in the 1940s for the double murder of h...   1994-09-23     133.983
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     124.166
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      74.940
# 3  The true story of how businessman Oskar Schind...   1993-12-15      95.181
# 4  A young girl, Chihiro, becomes trapped in a st...   2001-07-20      93.910
#
#    vote_average  vote_count
# 0         8.704       25650
# 1         8.696       19502
# 2         8.577       11783
# 3         8.566       15157
# 4         8.539       15558

# %%
#LOOP Use
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# all pages
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index = True)

# %%
df
# Out:
#           id                                  title  \
# 0        278               The Shawshank Redemption
# 1        238                          The Godfather
# 2        240                  The Godfather Part II
# 3        424                       Schindler's List
# 4        129                          Spirited Away
# ...      ...                                    ...
# 8555   13761  Pocahontas II: Journey to a New World
# 8556  442064                             Proud Mary
# 8557   50217                     From Prada to Nada
# 8558  378236                        The Emoji Movie
# 8559  244566                        Life After Beth
#
#                                                overview release_date  \
# 0     Framed in the 1940s for the double murder of h...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# ...                                                 ...          ...
# 8555  When news of John Smith's death reaches Americ...   1998-08-04
# 8556  Mary is a hit woman working for an organized c...   2018-01-12
# 8557  Two spoiled Beverly Hills sisters who have bee...   2011-01-28
# 8558  Gene, a multi-expressional emoji, sets out on ...   2017-07-23
# 8559  Zach is devastated by the unexpected death of ...   2014-08-15
#
#       popularity  vote_average  vote_count
# 0        133.983         8.704       25650
# 1        124.166         8.696       19502
# 2         74.940         8.577       11783
# 3         95.181         8.566       15157
# 4         93.910         8.539       15558
# ...          ...           ...         ...
# 8555      17.574         5.464        1275
# 8556      12.958         5.462         474
# 8557       9.097         5.462         315
# 8558      37.220         5.461        2908
# 8559      14.943         5.460         633
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')#convert csv
